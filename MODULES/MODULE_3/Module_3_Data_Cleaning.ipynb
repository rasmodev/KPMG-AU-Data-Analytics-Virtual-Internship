# %% [markdown]
# Install necessary libraries

# %%
#!pip install datasist

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import datasist as ds

# %%
# Read the data from the excelfile
df = pd.read_excel("KPMG_MODULE_3_Visualization Data.xlsx")
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0             253           2         3123       2017-12-30           0.0
# 1             411          62         3355       2017-12-30           0.0
# 2             497          62         1854       2017-12-30           1.0
# 3             606          70         2878       2017-12-30           0.0
# 4             748          80         2865       2017-12-30           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved  Giant Bicycles         Road           low        small  ...
# 1     Approved           Solex     Standard        medium       medium  ...
# 2     Approved           Solex     Standard          high       medium  ...
# 3     Approved   Trek Bicycles     Standard          high       medium  ...
# 4     Approved   Trek Bicycles     Standard        medium        large  ...
#
# ...

# %%
# Dataframe shape
df.shape
# Out:
# (20000, 44)

# %%
# Check the column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 44 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       20000 non-null  int64
#  1   product_id                           20000 non-null  int64
#  2   customer_id                          20000 non-null  int64
#  3   transaction_date                     20000 non-null  datetime64[ns]
#  4   online_order                         19640 non-null  float64
#  5   order_status                         20000 non-null  object
#  6   brand                                19803 non-null  object
#  7   product_line                         19803 non-null  object
#  8   product_class                        19803 non-null  object
#  9   product_size                         19803 non-null  object
#  10  list_price                           20000 non-null  float64
# ...

# %% [markdown]
# The dataset is properly formatted but has several unneccessary columns

# %%
# Drop Unnecessary Columns
columns_to_drop = [f"Unnamed: {i}" for i in range(30, 44)]
df = df.drop(columns=columns_to_drop)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       20000 non-null  int64
#  1   product_id                           20000 non-null  int64
#  2   customer_id                          20000 non-null  int64
#  3   transaction_date                     20000 non-null  datetime64[ns]
#  4   online_order                         19640 non-null  float64
#  5   order_status                         20000 non-null  object
#  6   brand                                19803 non-null  object
#  7   product_line                         19803 non-null  object
#  8   product_class                        19803 non-null  object
#  9   product_size                         19803 non-null  object
#  10  list_price                           20000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id                             0
# product_id                                 0
# customer_id                                0
# transaction_date                           0
# online_order                             360
# order_status                               0
# brand                                    197
# product_line                             197
# product_class                            197
# product_size                             197
# list_price                                 0
# standard_cost                            197
# product_first_sold_date                  197
# profit                                   727
# gender                                 18325
# past_3_years_bike_related_purchases    18325
# DOB                                    18325
# Age                                      727
# job_title                              18325
# job_industry_category                  18607
# wealth_segment                         18325
# ...

# %%
# Drop rows with missing values
df = df.dropna()

# Confirm if missing values have been handled
df.isnull().sum()
# Out:
# transaction_id                         0
# product_id                             0
# customer_id                            0
# transaction_date                       0
# online_order                           0
# order_status                           0
# brand                                  0
# product_line                           0
# product_class                          0
# product_size                           0
# list_price                             0
# standard_cost                          0
# product_first_sold_date                0
# profit                                 0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# Age                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# ...

# %%
# Check the column information of the cleaned dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1392 entries, 0 to 3325
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       1392 non-null   int64
#  1   product_id                           1392 non-null   int64
#  2   customer_id                          1392 non-null   int64
#  3   transaction_date                     1392 non-null   datetime64[ns]
#  4   online_order                         1392 non-null   float64
#  5   order_status                         1392 non-null   object
#  6   brand                                1392 non-null   object
#  7   product_line                         1392 non-null   object
#  8   product_class                        1392 non-null   object
#  9   product_size                         1392 non-null   object
#  10  list_price                           1392 non-null   float64
# ...

# %%
#Save cleaned data to a new csv file
df.to_csv('visualization_data.csv', index=False)

# %%
# Perform EDA with the datasist library
# Summary statistics
summary = ds.structdata.describe(df)
summary
# Out:
# First five data points
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0             253           2         3123       2017-12-30           0.0
# 1             411          62         3355       2017-12-30           0.0
# 3             606          70         2878       2017-12-30           0.0
# 4             748          80         2865       2017-12-30           1.0
# 5            1033          49          934       2017-12-30           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved  Giant Bicycles         Road           low        small  ...
# 1     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard          high       medium  ...
# 4     Approved   Trek Bicycles     Standard        medium        large  ...
# 5     Approved   Trek Bicycles         Road        medium       medium  ...
#
# ...
